# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadN98/Curso_Estatistica/blob/main/S4Exercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
dados_census = pd.read_csv("/content/drive/MyDrive/curso_estatistica/estatistica/Bases de dados/census.csv")
dados_census.head(3)
# Out:
# Mounted at /content/drive
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K

# %%
sns.histplot(dados_census['age'], bins=5)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(dados_census['age'], bins=3)
sns.histplot(dados_census['age'], bins=4)
sns.histplot(dados_census['age'], bins=5);

# %%
sns.histplot(dados_census['age'], bins=6)
sns.histplot(dados_census['age'], bins=7)
sns.histplot(dados_census['age'], bins=8)
;
# Out:
# ''

# %%
sns.histplot(dados_census['age'], bins='sturges')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#frequencia, classes = np.histogram(dados_census['age'], bins='sturges')
#plt.hist(dados_census['age'], classes);

# %%
dados_census['age'].max(), dados_census['age'].min()
# Out:
# (90, 17)

# %%
dados_census['age'] = pd.cut(dados_census['age'], bins=[0,17, 25, 40, 60, 90], labels=['Faixa1', 'Faixa2', 'Faixa3', 'Faixa4', 'Faixa5'])

# %%
dados_census.head()
# Out:
#       age          workclass  final-weight   education  education-num  \
# 0  Faixa3          State-gov         77516   Bachelors             13
# 1  Faixa4   Self-emp-not-inc         83311   Bachelors             13
# 2  Faixa3            Private        215646     HS-grad              9
# 3  Faixa4            Private        234721        11th              7
# 4  Faixa3            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %%
dados_census['age'].unique()
# Out:
# ['Faixa3', 'Faixa4', 'Faixa2', 'Faixa5', 'Faixa1']
# Categories (5, object): ['Faixa1' < 'Faixa2' < 'Faixa3' < 'Faixa4' < 'Faixa5']
