# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadN98/Curso_Estatistica/blob/main/S4_Distribuicao_de_frequencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Distribuicao de Frequencia

# %%
dados = np.array([160, 165, 167, 164, 160, 166, 160, 161, 150, 152, 173, 160, 155,
                  164, 168, 162, 161, 168, 163, 156, 155, 169, 151, 170, 164,
                  155, 152, 163, 160, 155, 157, 156, 158, 158, 161, 154, 161, 156, 172, 153
                  ])

# %% [markdown]
# ### Ordenacao

# %%
dados = np.sort(dados)
dados
# Out:
# array([150, 151, 152, 152, 153, 154, 155, 155, 155, 155, 156, 156, 156,
#        157, 158, 158, 160, 160, 160, 160, 160, 161, 161, 161, 161, 162,
#        163, 163, 164, 164, 164, 165, 166, 167, 168, 168, 169, 170, 172,
#        173])

# %%
max = dados.max()
min = dados.min()
min, max
# Out:
# (150, 173)

# %%
np.unique(dados, return_counts=True)
# Out:
# (array([150, 151, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163,
#         164, 165, 166, 167, 168, 169, 170, 172, 173]),
#  array([1, 1, 2, 1, 1, 4, 3, 1, 2, 5, 4, 1, 2, 3, 1, 1, 1, 2, 1, 1, 1, 1]))

# %%
sns.histplot(data=dados, bins=6)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Numero de classes
#
# - i = 1 +3.3 log n
# Formula de Struges

# %%
n = len(dados)

# %%
i = 1 +3.3 * np.log10(n)
i
# Out:
# 6.286797971382276

# %%
i = round(i)
i
# Out:
# 6

# %% [markdown]
# ### Amplitude do intervalo
#
# - h = AA / i
# - AA = Xmax - Xmin

# %%
AA = max - min
AA
# Out:
# 23

# %%
h = AA / i
h
# Out:
# 3.8333333333333335

# %%
h = math.ceil(h)
h
# Out:
# 4

# %% [markdown]
# ### Contrucao da distribuicao de frequencia

# %%
intervalos = np.arange(min, max + 2, step=h)
intervalos
# Out:
# array([150, 154, 158, 162, 166, 170, 174])

# %%
intervalo1, intervalo2, intervalo3, intervalo4, intervalo5, intervalo6 = 0,0,0,0,0,0
for i in range(n):
  if dados[i] >= intervalos[0] and dados[i] < intervalos[1]:
    intervalo1 += 1
  elif dados[i] >= intervalos[1] and dados[i] < intervalos[2]:
    intervalo2 += 1
  elif dados[i] >= intervalos[2] and dados[i] < intervalos[3]:
    intervalo3 += 1
  elif dados[i] >= intervalos[3] and dados[i] < intervalos[4]:
    intervalo4 += 1
  elif dados[i] >= intervalos[4] and dados[i] < intervalos[5]:
    intervalo5 += 1
  elif dados[i] >= intervalos[5] and dados[i] < intervalos[6]:
    intervalo6 += 1

# %%
lista_intervalos = []
lista_intervalos.append(intervalo1)
lista_intervalos.append(intervalo2)
lista_intervalos.append(intervalo3)
lista_intervalos.append(intervalo4)
lista_intervalos.append(intervalo5)
lista_intervalos.append(intervalo6)
lista_intervalos
# Out:
# [5, 9, 11, 7, 5, 3]

# %%
lista_classes = []
for i in range(len(lista_intervalos)):
  lista_classes.append(str(intervalos[i]) + '-' + str(intervalos[i + 1]))
lista_classes
# Out:
# ['150-154', '154-158', '158-162', '162-166', '166-170', '170-174']

# %%
sns.histplot(x=lista_classes, y=lista_intervalos, bins=5, fill=False)
# Out:
# <Axes: >

# %% [markdown]
# ### Hist com numpy e Matplot

# %%
frequencia , classes = np.histogram(dados)

# %%
frequencia , classes, len(classes)
# Out:
# (array([4, 2, 7, 3, 9, 3, 5, 3, 2, 2]),
#  array([150. , 152.3, 154.6, 156.9, 159.2, 161.5, 163.8, 166.1, 168.4,
#         170.7, 173. ]),
#  11)

# %%
plt.hist(dados, bins=classes)
# Out:
# (array([4., 2., 7., 3., 9., 3., 5., 3., 2., 2.]),
#  array([150. , 152.3, 154.6, 156.9, 159.2, 161.5, 163.8, 166.1, 168.4,
#         170.7, 173. ]),
#  <BarContainer object of 10 artists>)

# %%
frequencia, classes = np.histogram(dados, bins=5)
frequencia, classes
# Out:
# (array([ 6, 10, 12,  8,  4]),
#  array([150. , 154.6, 159.2, 163.8, 168.4, 173. ]))

# %%
plt.hist(dados, classes)
# Out:
# (array([ 6., 10., 12.,  8.,  4.]),
#  array([150. , 154.6, 159.2, 163.8, 168.4, 173. ]),
#  <BarContainer object of 5 artists>)

# %%
frequencia, classes = np.histogram(dados, bins='sturges')
#frequencia, classes
plt.hist(dados, classes)
# Out:
# (array([ 5.,  8.,  3., 12.,  5.,  4.,  3.]),
#  array([150.        , 153.28571429, 156.57142857, 159.85714286,
#         163.14285714, 166.42857143, 169.71428571, 173.        ]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# ### Distribuicao Pandas e Seaborn

# %%
type(dados)
# Out:
# numpy.ndarray

# %%
dataset = pd.DataFrame({'dados' : dados})
dataset.head()
# Out:
#    dados
# 0    150
# 1    151
# 2    152
# 3    152
# 4    153

# %%
dataset.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(dados);

# %%
dataset.head()
# Out:
#    dados
# 0    150
# 1    151
# 2    152
# 3    152
# 4    153

# %% [markdown]
# ### Regras de Associação
#
# - A base precisa estar em formato categorico, nao numerico

# %%
from google.colab import drive
drive.mount('/content/drive')
dados_census = pd.read_csv("/content/drive/MyDrive/curso_estatistica/estatistica/Bases de dados/census.csv")
dados_census.head(3)
# Out:
# Mounted at /content/drive
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K

# %%
dados_census['age'] = pd.cut(dados_census['age'], bins=[0,17, 25, 40, 60, 90], labels=['Faixa1', 'Faixa2', 'Faixa3', 'Faixa4', 'Faixa5'])

# %%
dados_census.head(3)
# Out:
#       age          workclass  final-weight   education  education-num  \
# 0  Faixa3          State-gov         77516   Bachelors             13
# 1  Faixa4   Self-emp-not-inc         83311   Bachelors             13
# 2  Faixa3            Private        215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K

# %%
apriori = dados_census[['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'sex', 'native-country', 'income']]

# %%
apriori.head(3), apriori.shape
# Out:
# (      age          workclass   education       marital-status  \
#  0  Faixa3          State-gov   Bachelors        Never-married
#  1  Faixa4   Self-emp-not-inc   Bachelors   Married-civ-spouse
#  2  Faixa3            Private     HS-grad             Divorced
#
#             occupation    relationship    sex  native-country  income
#  0        Adm-clerical   Not-in-family   Male   United-States   <=50K
#  1     Exec-managerial         Husband   Male   United-States   <=50K
#  2   Handlers-cleaners   Not-in-family   Male   United-States   <=50K  ,
#  (32561, 9))

# %%
apriori = apriori.sample(n=1000)
apriori.shape
# Out:
# (1000, 9)

# %%
lista_apriori = []
for i in range(apriori.shape[0]):
  lista_apriori.append([str(apriori.values[i, j]) for j in range(apriori.shape[1])])

# %%
lista_apriori
# Out:
# [['Faixa4',
#   ' Private',
#   ' HS-grad',
#   ' Married-civ-spouse',
#   ' Transport-moving',
#   ' Husband',
#   ' Male',
#   ' United-States',
#   ' >50K'],
#  ['Faixa5',
#   ' Self-emp-not-inc',
#   ' Some-college',
#   ' Widowed',
#   ' Farming-fishing',
#   ' Unmarried',
#   ' Female',
#   ' United-States',
#   ' <=50K'],
#  ['Faixa2',
#   ' Private',
#   ' Some-college',
#   ' Never-married',
#   ' Sales',
#   ' Not-in-family',
#   ' Male',
#   ' ?',
#   ' <=50K'],
#  ['Faixa3',
#   ' Private',
#   ' Masters',
#   ' Never-married',
#   ' Prof-specialty',
#   ' Not-in-family',
#   ' Male',
#   ' United-States',
#   ' <=50K'],
#  ['Faixa2',
#   ' Private',
#   ' 7th-8th',
#   ' Married-civ-spouse',
#   ' Handlers-cleaners',
#   ' Husband',
#   ' Male',
#   ' Mexico',
#   ' <=50K'],
#  ['Faixa4',
#   ' ?',
#   ' 5th-6th',
#   ' Married-civ-spouse',
#   ' ?',
#   ' Husband',
#   ' Male',
#   ' United-States',
#   ' >50K'],
#  ['Faixa3',
#   ' Private',
#   ' 12th',
# ...

# %%
len(lista_apriori)
# Out:
# 1000

# %%
lista_apriori[:2]
# Out:
# [['Faixa4',
#   ' Private',
#   ' HS-grad',
#   ' Married-civ-spouse',
#   ' Transport-moving',
#   ' Husband',
#   ' Male',
#   ' United-States',
#   ' >50K'],
#  ['Faixa5',
#   ' Self-emp-not-inc',
#   ' Some-college',
#   ' Widowed',
#   ' Farming-fishing',
#   ' Unmarried',
#   ' Female',
#   ' United-States',
#   ' <=50K']]

# %%
# !pip install apyori
from apyori import apriori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=d533117dcea3727442e8a6ea3f057b190881827b76f3fc12463e5c071f148e1a
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
regras = apriori(lista_apriori, min_support=0.3, min_confidence=0.2)
resultado = list(regras)
resultado
# Out:
# [RelationRecord(items=frozenset({' <=50K'}), support=0.76, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K'}), confidence=0.76, lift=1.0)]),
#  RelationRecord(items=frozenset({' Female'}), support=0.33, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Female'}), confidence=0.33, lift=1.0)]),
#  RelationRecord(items=frozenset({' HS-grad'}), support=0.311, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' HS-grad'}), confidence=0.311, lift=1.0)]),
#  RelationRecord(items=frozenset({' Husband'}), support=0.424, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband'}), confidence=0.424, lift=1.0)]),
#  RelationRecord(items=frozenset({' Male'}), support=0.67, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male'}), confidence=0.67, lift=1.0)]),
# ...

# %%
len(resultado)
# Out:
# 35

# %%
resultado[12]
# Out:
# RelationRecord(items=frozenset({' <=50K', ' Never-married'}), support=0.304, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K', ' Never-married'}), confidence=0.304, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Never-married'}), confidence=0.39999999999999997, lift=1.2269938650306746), OrderedStatistic(items_base=frozenset({' Never-married'}), items_add=frozenset({' <=50K'}), confidence=0.9325153374233128, lift=1.2269938650306749)])
